# %% [markdown]
# ### Method - Deleting rows or column

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('train.csv')

# %%
pd.set_option('display.max_columns',None) # To display all the columns
pd.set_option('display.max_rows',None) # To display all the rows

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum() # to calculate the total numbers of null value in column
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.isnull()) # in this heatmap the white lines means the null values
# Out:
# <Axes: >

# %%
null_var = df.isnull().sum()/df.shape[0]*100 # calculating the total percentage of null values in all columns
null_var
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       59.726027
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
drop_columns = null_var[null_var > 17].keys() # Extracting the columns which have null values greater than 17% so that we can delete the entire column
drop_columns
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
df2_drop_col = df.drop(columns = drop_columns) # The new dataframe after deleting the columns with null values

# %%
df2_drop_col.shape
# Out:
# (1460, 74)

# %%
sns.heatmap(df2_drop_col.isnull())
# Out:
# <Axes: >

# %%
df3_drop_row = df2_drop_col.dropna() # Deleting the entire null where the null value is present

# %%
df3_drop_row.shape
# Out:
# (1338, 74)

# %%
sns.heatmap(df3_drop_row.isnull()) # here the heatmap is clear so there are no any null values
# Out:
# <Axes: >

# %%
df3_drop_row.select_dtypes(include = ['int64','float64']).columns # Extracting all the columns with int and float datatypes
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
sns.distplot(df['MSSubClass'])
sns.distplot(df3_drop_row['MSSubClass'])

# checking the distribution of data with respect to single feature after cleaning with respect to original
# Here both the figures are overlapped , slight difference so clearing the null values doesnot affect so much on this column
# Out:
# <Axes: xlabel='MSSubClass', ylabel='Density'>

# %%
## Now lets check the distrubition of all the features which has numeric values

num_var = ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
       'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
       'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
       'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
       'MoSold', 'YrSold', 'SalePrice']

plt.figure(figsize=(25,25))
for i , var in enumerate(num_var):
    plt.subplot(9,4,i+1)  # here (9,4) means there are total 36 columns with numeric values and we want 9 rows and 4 columns
    sns.distplot(df[var],bins = 20)
    sns.distplot(df3_drop_row[var], bins = 20)

# %%
# now we see the data distribution of caterogical data
caterogical = df3_drop_row.select_dtypes(include = ['object']).columns # Extracting all the columns with caterogical datatypes
caterogical
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
print(df['MSZoning'].value_counts()) # checking the unique values in the column of original dataset
print()
print(df['MSZoning'].value_counts()/df.shape[0]*100) # checking the percentage of unique values in the column of original dataset
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
#
# MSZoning
# RL         78.835616
# RM         14.931507
# FV          4.452055
# RH          1.095890
# C (all)     0.684932
# Name: count, dtype: float64

# %%
# Now lets check the percentage of unique values in all the caterogical columns in original dataset as well as in cleaned dataset of single feature

pd.concat([df['MSZoning'].value_counts()/df.shape[0]*100, 
           df3_drop_row['MSZoning'].value_counts()/df3_drop_row.shape[0]*100], axis = 1, keys = ['MSZoning_org','MSZoning_cleaned'])
# Out:
#           MSZoning_org  MSZoning_cleaned
# MSZoning
# RL           78.835616         79.671151
# RM           14.931507         14.275037
# FV            4.452055          4.633782
# RH            1.095890          0.822123
# C (all)       0.684932          0.597907

# %%
def cat_var_dist(var):
    return pd.concat([df[var].value_counts()/df.shape[0]*100, 
           df3_drop_row[var].value_counts()/df3_drop_row.shape[0]*100], axis = 1, keys = [var+'_org',var+'_cleaned'])

# %%
caterogical = df3_drop_row.select_dtypes(include=['object']).columns
caterogical
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
for col in caterogical:
    fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
    
    # Plot for the original dataset with null values
    sns.histplot(df[col].dropna(), ax=axes[0], kde=False, discrete=True)
    axes[0].set_title(f'Original {col}')
    axes[0].set_xlabel(col)
    axes[0].set_ylabel('Frequency')
    
    # Plot for the cleaned dataset
    sns.histplot(df3_drop_row[col], ax=axes[1], kde=False, discrete=True)
    axes[1].set_title(f'Cleaned {col}')
    axes[1].set_xlabel(col)
    axes[1].set_ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()
